# %%
import time
from mydate import *
from selenium import webdriver
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_argument('--window-size=1920,1080')
# options.add_argument('--headless')
options.add_argument('--no-sandbox')
# options.add_argument('--disable-dev-shm-usage')
options.add_argument("--user-agent='Mozilla/5.0 (Linux; Android 4.4.2; Nexus 4 Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.122 Mobile Safari/537.36 UCBrowser'")
driver = webdriver.Chrome(options=options)

driver.get('https://www.gtarsc.com/')

time.sleep(5)

i_frame = driver.find_element(By.TAG_NAME, 'iframe').get_attribute('src')

driver.get(i_frame)
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "En")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "简体")]')[0].click()
time.sleep(5)

try:
    driver.find_element(By.XPATH, '//*[@id="csmar-app"]/div/div[4]/div/img[2]').click()
    time.sleep(5)
except:
    pass

driver.find_elements(By.XPATH, '//*[contains(text(), "数据中心")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "单表查询")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "基金市场系列")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "公募基金")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "基金概况")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "基金主体信息表")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "CSV格式（*.csv）")]')[0].click()
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "下载数据")]')[-1].click()
time.sleep(5)

driver.switch_to.window(driver.window_handles[1])
time.sleep(5)

driver.find_elements(By.XPATH, '//*[contains(text(), "本地保存数据")]')[0].click()
time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[19], line 19
#      15 driver.get('https://www.gtarsc.com/')
#      17 time.sleep(5)
# ---> 19 i_frame = driver.find_element(By.TAG_NAME, 'iframe').get_attribute('src')
#      21 driver.get(i_frame)
#      22 time.sleep(5)
#
# File c:\Users\11633\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\11633\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File c:\Users\11633\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"tag name","selector":"iframe"}
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0082F243]
# 	(No symbol) [0x007B7FD1]
# 	(No symbol) [0x006AD04D]
# 	(No symbol) [0x006DC0B0]
# 	(No symbol) [0x006DC22B]
# 	(No symbol) [0x0070E612]
# 	(No symbol) [0x006F85D4]
# 	(No symbol) [0x0070C9EB]
# 	(No symbol) [0x006F8386]
# 	(No symbol) [0x006D163C]
# 	(No symbol) [0x006D269D]
# 	GetHandleVerifier [0x00AC9A22+2655074]
# 	GetHandleVerifier [0x00ABCA24+2601828]
# 	GetHandleVerifier [0x008D8C0A+619850]
# 	GetHandleVerifier [0x008D7830+614768]
# 	(No symbol) [0x007C05FC]
# 	(No symbol) [0x007C5968]
# 	(No symbol) [0x007C5A55]
# 	(No symbol) [0x007D051B]
# 	BaseThreadInitThunk [0x75DB7D69+25]
# 	RtlInitializeExceptionChain [0x775BBB9B+107]
# 	RtlClearBits [0x775BBB1F+191]

# %%
start_date = driver.find_elements(By.XPATH, '//*[@class="date-range-picker table-picker"]//input')[0]
start_date.clear()
start_date.send_keys(day_yesterday)
end_date = driver.find_elements(By.XPATH, '//*[@class="date-range-picker table-picker"]//input')[1]
end_date.clear()
end_date.send_keys(day_today)

# %%
from utils.threaded_df_to_mysql import threaded_df_to_mysql

# %%
from utils.set_mysql_table_index import set_mysql_table_index

# %%
from utils.fetch_from_mysql import fetch_from_mysql

# %%
import dask.dataframe as ddf

df = ddf.read_csv('data/CSMAR/index_weight/*', low_memory=False, dtype={'Indexcd': 'object'}).compute()
# threaded_df_to_mysql(df, host='localhost', user='root', password='Doushi0930!', database='csmar', port=38321, TABLE_NAME='IDX_Smprat', PARTITIONS=1000, N_WORKERS=8, THREADS_PER_WORKER=1)
df
# Out:
#       Indexcd       Enddt   Stkcd Constdnme  Weight
# 0      000010  2007-10-15  600331      宏达股份   0.480
# 1      000010  2007-10-15  600345      长江通信   0.030
# 2      000010  2007-10-15  600348      国阳新能   0.330
# 3      000010  2007-10-15  600350      山东高速   0.150
# 4      000010  2007-10-15  600357      承德钒钛   0.330
# ...       ...         ...     ...       ...     ...
# 54841  H00160  2022-11-30  600583      海油工程   0.563
# 54842  H00160  2022-11-30  600011      华能国际   1.519
# 54843  H00160  2022-11-30  600029      南方航空   1.789
# 54844  H00160  2022-11-30  601808      中海油服   0.467
# 54845  H00160  2022-11-30  601866      中远海发   0.463
#
# [9276750 rows x 5 columns]
